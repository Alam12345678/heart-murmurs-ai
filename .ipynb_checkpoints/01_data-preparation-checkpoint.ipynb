# %% [markdown]
# # Install & import packages and get the data

# %%
import os
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_5480/1621667384.py in <module>
#       1 import os
# ----> 2 import librosa
#       3 import librosa.display
#       4 import IPython.display as ipd
#       5 import numpy as np
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/librosa/__init__.py in <module>
#     209 # And all the librosa sub-modules
#     210 from ._cache import cache
# --> 211 from . import core
#     212 from . import beat
#     213 from . import decompose
#
# ~/miniconda3/envs/fastai/lib/python3.7/site-packages/librosa/core/__init__.py in <module>
#       3 """ Core IO and DSP functions"""
#       4
# ----> 5 from .convert import *  # pylint: disable=wildcard-import
#       6 from .audio import *  # pylint: disable=wildcard-import
#       7 from .spectrum import *  # pylint: disable=wildcard-import
#
# ...

# %%
#!pip install librosa 
# !pip install numpy==1.19.5
# Out:
# ...
#      |████████████████████████████████| 14.8 MB 13.3 MB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
# ...

# %%
from fastai.vision.all import *
import os
import wave

import pylab

# %%
path = Path('dataset')

# %%
(path/'N').ls().sorted()
# Out:
# (#200) [Path('dataset/N/New_N_001.wav'),Path('dataset/N/New_N_002.wav'),Path('dataset/N/New_N_003.wav'),Path('dataset/N/New_N_004.wav'),Path('dataset/N/New_N_005.wav'),Path('dataset/N/New_N_006.wav'),Path('dataset/N/New_N_007.wav'),Path('dataset/N/New_N_008.wav'),Path('dataset/N/New_N_009.wav'),Path('dataset/N/New_N_010.wav')...]

# %% [markdown]
# # Generate the image files from heart sound files
#
# We will convert the sound file (.wav) into spectogram and save it as PNG files

# %%
def sound_image_generator(path):
    files = path.ls().sorted()
    for f in files:
        print('Converting file '+ str(f))
        wav = wave.open(str(f), 'r')
        frames = wav.readframes(-1)
        sound_info = pylab.frombuffer(frames, 'int16')
        frame_rate = wav.getframerate()
        wav.close()
        
        #
#         sound_info, frame_rate = get_wav_info(wav_file)
#         pylab.figure(num=None, figsize=(5, 5))
#         pylab.subplot(111)
        # pylab.title('spectrogram of %r' % wav_file)
        pylab.specgram(sound_info, Fs=frame_rate)
        pylab.savefig(str(f'{path/f.stem}'))
        
sound_image_generator(path/'N')
# Out:
# Converting file dataset/N/New_N_001.wav
# Converting file dataset/N/New_N_002.wav
# Converting file dataset/N/New_N_003.wav
# Converting file dataset/N/New_N_004.wav
# Converting file dataset/N/New_N_005.wav
# Converting file dataset/N/New_N_006.wav
# Converting file dataset/N/New_N_007.wav
# Converting file dataset/N/New_N_008.wav
# Converting file dataset/N/New_N_009.wav
# Converting file dataset/N/New_N_010.wav
# Converting file dataset/N/New_N_011.wav
# Converting file dataset/N/New_N_012.wav
# Converting file dataset/N/New_N_013.wav
# Converting file dataset/N/New_N_014.wav
# Converting file dataset/N/New_N_015.wav
# Converting file dataset/N/New_N_016.wav
# Converting file dataset/N/New_N_017.wav
# Converting file dataset/N/New_N_018.wav
# Converting file dataset/N/New_N_019.wav
# Converting file dataset/N/New_N_020.wav
# Converting file dataset/N/New_N_021.wav
# Converting file dataset/N/New_N_022.wav
# Converting file dataset/N/New_N_023.wav
# ...

# %%
def get_wav_info(wav_file):
    wav = wave.open(wav_file, 'r')
    frames = wav.readframes(-1)
    sound_info = pylab.frombuffer(frames, 'int16')
    frame_rate = wav.getframerate()
    wav.close()
    return sound_info, frame_rate

def graph_spectrogram(wav_file):
    sound_info, frame_rate = get_wav_info(wav_file)
    plt.imshow(spectrogram)
#     pylab.figure(num=None, figsize=(5, 5))
#     pylab.subplot(111)
#     pylab.title('spectrogram of %r' % wav_file)
    pylab.specgram(sound_info, Fs=frame_rate)
    pylab.savefig('spectrogram.png')

# %%
graph_spectrogram('dataset/N/New_N_001.wav')

# %%
graph_spectrogram(f'{path}/AS/New_AS_001.wav')

# %%
graph_spectrogram(f'{path}/MR/New_MR_001.wav')

# %%
graph_spectrogram(f'{path}/MS/New_MS_001.wav')

# %%
graph_spectrogram(f'{path}/MVP/New_MVP_001.wav')
