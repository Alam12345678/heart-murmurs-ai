# %% [markdown]
# # Install & import packages

# %% [markdown]
# >If you do not have the librosa library you may install it with **pip install librosa**

# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5368/2566296125.py in <module>
#       1 #hide
#       2 get_ipython().system('pip install -Uqq fastbook')
# ----> 3 import fastbook
#       4 fastbook.setup_book()
#
# ModuleNotFoundError: No module named 'fastbook'

# %%
import os
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
# from fastbook import *
import soundfile as sf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5368/2919034267.py in <module>
#       1 import os
# ----> 2 import librosa
#       3 import librosa.display
#       4 import IPython.display as ipd
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'librosa'

# %% [markdown]
# # Data Loading & Exploring Data Analysis

# %%
path = Path('/content/gdrive/MyDrive/ML/heart-murmurs-ai/dataset')

# %% [markdown]
# #### 1. Normal Valves

# %%
f = path/'all_files/New_N_001.wav'
ipd.Audio(str(f))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 2. Aortic Stenosis

# %%
f = path/'all_files/New_AS_001.wav'
ipd.Audio(str(f))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 3. Mitral Stenosis

# %%
f = path/'all_files/New_MS_001.wav'
ipd.Audio(str(f))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 4. Mitral Regurgitation

# %%
f = path/'all_files/New_MR_001.wav'
ipd.Audio(str(f))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 5. Mitral Valve Prolapse

# %%
f = path/'all_files/New_MVP_001.wav'
ipd.Audio(str(f))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Building Utility Functions

# %%
'''
Function for applying following transforms on the wave files:
1. Noise Addition using normal distribution of mean =0 and std =1
2. Shifting Sound wave
3. Time-stretching
4. Pitch - shifting of a wave
'''

def audio_data_transforms(wav_file_path:str, tfms_folder_path:str) -> None:
  fname = str(wav_file_path).split('/')[-1].split('.')[0]
  wav, sr = librosa.load(wav_file_path,sr=None)

  #tfms 1: Noise addition:
  wav_n = wav + 0.009*np.random.normal(0,1,len(wav))

  #tfms 2: Shifting Sound wave:
  wav_roll = np.roll(wav,int(sr/10))

  #tfms 3: Time - stretching
  factor = 0.4
  wav_time_stch = librosa.effects.time_stretch(wav,factor)

  #tfms 4: Pitch - Shifting
  wav_pitch_sf = librosa.effects.pitch_shift(wav,sr,n_steps=-5)

  wav_tfms = [wav_n,wav_roll,wav_time_stch,wav_pitch_sf]

  sf.write(f'{tfms_folder_path}/{fname}_noise.wav', wav_n, sr)
  sf.write(f'{tfms_folder_path}/{fname}_sshifting.wav', wav_roll, sr)
  sf.write(f'{tfms_folder_path}/{fname}_stretch.wav', wav_time_stch, sr)
  sf.write(f'{tfms_folder_path}/{fname}_pshift.wav', wav_pitch_sf, sr)

# %%
'''
Function for converting all the waves files to image files.
'''

def generate_images_from_files(audio_path:str, spec_path:str):
  
  for file_path in progress_bar(audio_path.ls()):
    fname = str(file_path).split('/')[-1].split('.')[0]

    samples, sample_rate = librosa.load(file_path,sr=None)

    fig, ax = plt.subplots(figsize=(5,5))
    ax.set_axis_off()
    ax.specgram(samples,Fs=2);
    fig.savefig(spec_path/f'{fname}.png',bbox_inches="tight",pad_inches=0)
    plt.close(fig)
    del sample_rate, samples, fig, ax

# %% [markdown]
# # Data Augmentation
#
# >We will create more audio files through data augmentation and save them into **aug_files** folder

# %%
# !mkdir aug_files

# %%
path/'orig_files'
# Out:
# Path('/content/gdrive/MyDrive/ML/heart-murmurs-ai/dataset/orig_files')

# %%
len((path/'orig_files').ls())
# Out:
# 1000

# %%
for f in progress_bar((path/'orig_files').ls()): audio_data_transforms(f,path/'aug_files')
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 02:12<00:00]
#     </div>

# %%
len((path/'aug_files').ls())
# Out:
# 4000

# %% [markdown]
# Merging files

# %%
# !cp -a {path}/orig_files/. {path}/all_files
# !cp -a {path}/aug_files/. {path}/all_files

# %%
assert len((path/'all_files').ls()) == 5000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0379cf3d8b36> in <module>()
# ----> 1 assert len((path/'all_files').ls()) == 5000
#
# NameError: name 'path' is not defined

# %%
generate_images_from_files(path/'all_files', path/'images')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d3b19ce20e73> in <module>()
# ----> 1 generate_images_from_files(path/'all_files', path/'images')
#
# NameError: name 'generate_images_from_files' is not defined

# %%
len((path/'images').ls())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aabb32c476a5> in <module>()
# ----> 1 len((path/'images').ls())
#
# NameError: name 'path' is not defined

# %% [markdown]
# # Building the dataset

# %%
img_path = Path('/content/gdrive/MyDrive/ML/heart-murmurs-ai/dataset/images')

#Data Frame containing of file names with label so as to form structred folder
label_list = [str(f_path).split('/')[-1].replace('New_','').split('_')[0] for f_path in img_path.ls()]
fnames = [str(f_path).split('/')[-1] for f_path in img_path.ls()]
# fnames = [str(f_path) for f_path in img_path.ls()]
df = pd.DataFrame({'fnames':fnames, 'labels':label_list})
df.head()
# Out:
#             fnames labels
# 0   New_MR_175.png     MR
# 1  New_MVP_008.png    MVP
# 2   New_AS_084.png     AS
# 3   New_AS_081.png     AS
# 4    New_N_188.png      N

# %%
df['labels'].value_counts().plot.bar();

# %%
dblock = DataBlock(blocks= (ImageBlock,CategoryBlock),
                   get_items=get_image_files,
                   get_x = lambda x: x,
                   get_y = lambda x: str(x).split('/')[-1].replace('New_','').split('_')[0],
                   splitter = RandomSplitter(valid_pct=0.2, seed=42),
                   item_tfms=Resize(224)
                  )

# %%
dls = dblock.datasets(img_path)
dls[0]
dls.vocab
# Out:
# ['AS', 'MR', 'MS', 'MVP', 'N']

# %%
dblock.summary(img_path)
# Out:
# Setting-up type transforms pipelines
# Collecting items from /content/gdrive/MyDrive/ML/heart-murmurs-ai/dataset/images
# Found 1000 items
# 2 datasets of sizes 800,200
# Setting up Pipeline: <lambda> -> PILBase.create
# Setting up Pipeline: <lambda> -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#
# Building one sample
#   Pipeline: <lambda> -> PILBase.create
#     starting from
#       /content/gdrive/MyDrive/ML/heart-murmurs-ai/dataset/images/New_MVP_052.png
#     applying <lambda> gives
#       /content/gdrive/MyDrive/ML/heart-murmurs-ai/dataset/images/New_MVP_052.png
#     applying PILBase.create gives
#       PILImage mode=RGB size=279x271
#   Pipeline: <lambda> -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#     starting from
#       /content/gdrive/MyDrive/ML/heart-murmurs-ai/dataset/images/New_MVP_052.png
#     applying <lambda> gives
#       MVP
#     applying Categorize -- {'vocab': None, 'sort': True, 'add_na': False} gives
#       TensorCategory(3)
#
# Final sample: (PILImage mode=RGB size=279x271, TensorCategory(3))
#
#
# Collecting items from /content/gdrive/MyDrive/ML/heart-murmurs-ai/dataset/images
# Found 1000 items
# 2 datasets of sizes 800,200
# Setting up Pipeline: <lambda> -> PILBase.create
# Setting up Pipeline: <lambda> -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
# Setting up after_item: Pipeline: Resize -- {'size': (24, 24), 'method': 'crop', 'pad_mode': 'reflection', 'resamples': (2, 0), 'p': 1.0} -> ToTensor
# Setting up before_batch: Pipeline:
# Setting up after_batch: Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}
#
# Building one batch
# Applying item_tfms to the first sample:
#   Pipeline: Resize -- {'size': (24, 24), 'method': 'crop', 'pad_mode': 'reflection', 'resamples': (2, 0), 'p': 1.0} -> ToTensor
#     starting from
#       (PILImage mode=RGB size=279x271, TensorCategory(3))
#     applying Resize -- {'size': (24, 24), 'method': 'crop', 'pad_mode': 'reflection', 'resamples': (2, 0), 'p': 1.0} gives
#       (PILImage mode=RGB size=24x24, TensorCategory(3))
#     applying ToTensor gives
#       (TensorImage of size 3x24x24, TensorCategory(3))
#
# Adding the next 3 samples
#
# No before_batch transform to apply
#
# Collating items in a batch
#
# Applying batch_tfms to the batch built
#   Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}
#     starting from
#       (TensorImage of size 4x3x24x24, TensorCategory([3, 0, 4, 0]))
#     applying IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} gives
#       (TensorImage of size 4x3x24x24, TensorCategory([3, 0, 4, 0]))

# %%
dls=dblock.dataloaders(img_path, bs=64)

# %%
dls.show_batch(figsize=(5,5))

# %% [markdown]
# # Training Model

# %%
learn = cnn_learner(dls, models.resnet34, metrics=[accuracy])

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=0.0012022644514217973)

# %%
learn.fit_one_cycle(15,1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.620030</td>
#       <td>1.761985</td>
#       <td>0.305000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.218539</td>
#       <td>1.373152</td>
#       <td>0.390000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.834409</td>
#       <td>0.817964</td>
#       <td>0.700000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.485040</td>
#       <td>0.647295</td>
#       <td>0.805000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.214476</td>
#       <td>0.545913</td>
#       <td>0.815000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.042965</td>
#       <td>0.473882</td>
#       <td>0.835000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.903829</td>
#       <td>0.402311</td>
#       <td>0.850000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.764755</td>
#       <td>0.409648</td>
#       <td>0.850000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.671708</td>
#       <td>0.375962</td>
#       <td>0.880000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.597182</td>
#       <td>0.385093</td>
#       <td>0.855000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.533645</td>
#       <td>0.359597</td>
#       <td>0.875000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.479266</td>
#       <td>0.356964</td>
#       <td>0.885000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.433061</td>
#       <td>0.351666</td>
#       <td>0.895000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.403171</td>
#       <td>0.345445</td>
#       <td>0.900000</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.385003</td>
#       <td>0.333834</td>
#       <td>0.890000</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(6,6), dpi=60)
